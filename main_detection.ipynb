# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# !git reset --hard fbe67e465375231474a2ad80a4389efc77ecff99

# %%
import torch

from IPython.display import Image, clear_output  # to display images
from yolov5.utils.downloads import attempt_download  # to download models/datasets


if torch.cuda.is_available():
    print('Using GPU')
    print('Torch Version', torch.__version__)
    print(torch.cuda.get_device_properties(0))
    device = torch.device('cuda:0')
else:
    print('Using CPU')
# Out:
# Using GPU
# Torch Version 2.0.0+cu117
# _CudaDeviceProperties(name='NVIDIA GeForce RTX 3060 Laptop GPU', major=8, minor=6, total_memory=6143MB, multi_processor_count=30)

# %%
import yaml
with open("./yolov5/data/data.yaml", 'r') as stream:
    num_classes = str(yaml.safe_load(stream)['nc'])
    print(num_classes)
# Out:
# 3

# %%
# !where python
# Out:
# C:\Users\samuel\pyenv\torch_gpu1\Scripts\python.exe
# C:\Users\samuel\AppData\Local\Programs\Python\Python39\python.exe
# C:\Users\samuel\AppData\Local\Microsoft\WindowsApps\python.exe

# %%
# !python ./yolov5/train.py --img 256 --batch 8 --epochs 100 --data ./yolov5/data/data.yaml --cfg ./yolov5/models/custom_yolov5s.yaml --name yolov5s_results  --cache
# Out:
# ^C

# %%
# !cd
# Out:
# d:\torch_adv\tracking

# %%
# we can also output some older school graphs if the tensor board isn't working for whatever reason... 
from utils.plots import plot_results  # plot results.txt as results.png
from PIL import Image
Image.open('./runs/train/yolov5s_results15/results.png')
# Image.open(filename='/content/yolov5/runs/train/yolov5s_results/results.png', width=1000)  # view results.png
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2400x1200>

# %%
print("GROUND TRUTH TRAINING DATA:")
Image.open('./runs/train/yolov5s_results15/train_batch0.jpg')
# Out:
# GROUND TRUTH TRAINING DATA:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=768x768>

# %%
print("GROUND TRUTH TRAINING DATA:")
Image(filename='/content/yolov5/runs/train/yolov5s_results15/train_batch0_labels.jpg', width=900)

# %%
# !python ./detect.py --weights ./runs/train/yolov5s_results15/weights/best.pt --img 416 --conf 0.4 --source ./data/test/images
